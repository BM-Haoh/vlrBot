# %% [markdown]
# # V2.0 - Adaptando tudo para o banco de dados

# %% [markdown]
# ## Passo a Passo:

# %% [markdown]
# v2.0
# - new_api_handler.py -> desuso
# - Criar um DB_handler.py
#     - Publicar leitura de partidas no Banco de Dados
#     - Ler informações do banco de dados para consulta
#     - ids (de partidas): não mais arbitrários, agora os mesmos do vlr
# - Mudar a lógica do auto.py
#     - Selenium deve rodar no modo headless
#     - Logica de Ctrl + clique -> desuso
#     - Trocar por: lista de links
#     - Ler um camps.txt que tem o link dos campeonatos
#     - Se camp = completo, reescrever txt para remover o link do camp
#     - **Automatizar com git Actions**
# - Mudar a lógica do bot
#     - Comandos devem ler a informação desejada do banco de dados, e não dos jsons
#     - Subir o bot para algum site?
#
# v2.5
# Algumas mudanças foram feitas direto no .py
#
# - Automatizar mudança da map pool       (DB_handler)
# - Automatizar adição de mapa            (DB_handler)
# - Salvar tabelas de stats               (auto.py)
#     - Adaptar Stats_manager()
#     - Salvar só quando estiver completo, ou sempre que tiver mais jogos?

# %% [markdown]
# ## Start

# %%
# Inicializando Selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
import os

# Headless - pode funcionar diferente
options = webdriver.ChromeOptions()
options.add_argument('--headless')
navegador = webdriver.Chrome(options=options)

link = 'https://www.vlr.gg/event/matches/2682/vct-2026-americas-kickoff'

# %%
# Abrindo o site
navegador.get(link)

# %% [markdown]
# ## V2.0

# %% [markdown]
# ### Get Camp

# %%
camp = navegador.find_element(By.CLASS_NAME, 'wf-title').text
display(camp)
# Out:
# 'VCT 2026: Americas Kickoff'

# %% [markdown]
# ### Get Matches

# %%
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

# %%
matches = navegador.find_elements(By.CLASS_NAME, 'match-item')
matches_links = [match.get_attribute("href") for match in matches]

pri_win = navegador.window_handles[0]
for match in matches_links:
    display(match)
    # ActionChains(navegador).key_down(Keys.CONTROL).click(match).key_up(Keys.CONTROL).perform()
    # sleep(.5)
    # seg_win = navegador.window_handles[1]
    # navegador.switch_to.window(seg_win)

    # display(navegador.find_element(By.CLASS_NAME, 'match-header-vs').text)
    # navegador.close()
    # sleep(.5)
    # navegador.switch_to.window(pri_win)
# Out:
# 'https://www.vlr.gg/596399/envy-vs-evil-geniuses-vct-2026-americas-kickoff-ur1'
# 'https://www.vlr.gg/596398/loud-vs-cloud9-vct-2026-americas-kickoff-ur1'
# 'https://www.vlr.gg/596400/kr-esports-vs-furia-vct-2026-americas-kickoff-ur1'
# 'https://www.vlr.gg/596401/100-thieves-vs-leviat-n-vct-2026-americas-kickoff-ur1'
# 'https://www.vlr.gg/596402/nrg-vs-cloud9-vct-2026-americas-kickoff-ur2'
# 'https://www.vlr.gg/596403/mibr-vs-envy-vct-2026-americas-kickoff-ur2'
# 'https://www.vlr.gg/596404/sentinels-vs-furia-vct-2026-americas-kickoff-ur2'
# 'https://www.vlr.gg/596405/g2-esports-vs-100-thieves-vct-2026-americas-kickoff-ur2'
# 'https://www.vlr.gg/596409/loud-vs-100-thieves-vct-2026-americas-kickoff-mr1'
# 'https://www.vlr.gg/596410/evil-geniuses-vs-sentinels-vct-2026-americas-kickoff-mr1'
# 'https://www.vlr.gg/596411/kr-esports-vs-envy-vct-2026-americas-kickoff-mr1'
# 'https://www.vlr.gg/596412/leviat-n-vs-cloud9-vct-2026-americas-kickoff-mr1'
# 'https://www.vlr.gg/596413/100-thieves-vs-sentinels-vct-2026-americas-kickoff-mr2'
# 'https://www.vlr.gg/596414/envy-vs-cloud9-vct-2026-americas-kickoff-mr2'
# 'https://www.vlr.gg/596406/nrg-vs-mibr-vct-2026-americas-kickoff-ur3'
# 'https://www.vlr.gg/596407/furia-vs-g2-esports-vct-2026-americas-kickoff-ur3'
# 'https://www.vlr.gg/596419/loud-vs-evil-geniuses-vct-2026-americas-kickoff-lr1'
# 'https://www.vlr.gg/596420/kr-esports-vs-leviat-n-vct-2026-americas-kickoff-lr1'
# 'https://www.vlr.gg/596415/nrg-vs-100-thieves-vct-2026-americas-kickoff-mr3'
# 'https://www.vlr.gg/596416/g2-esports-vs-cloud9-vct-2026-americas-kickoff-mr3'
# 'https://www.vlr.gg/596421/envy-vs-evil-geniuses-vct-2026-americas-kickoff-lr2'
# 'https://www.vlr.gg/596422/sentinels-vs-leviat-n-vct-2026-americas-kickoff-lr2'
# 'https://www.vlr.gg/596423/100-thieves-vs-evil-geniuses-vct-2026-americas-kickoff-lr3'
# 'https://www.vlr.gg/596424/cloud9-vs-leviat-n-vct-2026-americas-kickoff-lr3'
# 'https://www.vlr.gg/596417/nrg-vs-g2-esports-vct-2026-americas-kickoff-mr4'
# 'https://www.vlr.gg/596425/100-thieves-vs-cloud9-vct-2026-americas-kickoff-lr4'
# 'https://www.vlr.gg/596408/mibr-vs-furia-vct-2026-americas-kickoff-ubf'
# 'https://www.vlr.gg/596426/nrg-vs-100-thieves-vct-2026-americas-kickoff-lr5'
# 'https://www.vlr.gg/596418/mibr-vs-g2-esports-vct-2026-americas-kickoff-mbf'
# 'https://www.vlr.gg/596427/mibr-vs-nrg-vct-2026-americas-kickoff-lbf'

# %% [markdown]
# ## v2.5

# %% [markdown]
# ### Sts manager

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
import os
import pandas as pd

import psycopg
import os
from dotenv import load_dotenv

# %%
# Headless - pode funcionar diferente
options = webdriver.ChromeOptions()
options.add_argument('--headless')
browser = webdriver.Chrome(options=options)
link = 'https://www.vlr.gg/event/2685/vct-2026-china-kickoff/main-event'
browser.get(link)

# %% [markdown]
# #### defs

# %%
load_dotenv()
DB_URL = os.getenv("DATABASE_URL")
def get_conn():
            return psycopg.connect(DB_URL)

# %%
def stats_table(camp_link=None):
        '''
        Getting the parameters for creating an pandas table of players' stats

        :return table: matrix with all the values for each row of stats
        :return columns: Array with strings containing the columns' names
        '''
        if camp_link:
            browser.get(camp_link)

        # Finding and opening the page with the tournament's stats info
        nav_itens = browser.find_elements(By.CLASS_NAME, 'wf-nav-item')
        for item in nav_itens:
            if 'stats' in item.get_attribute('href'):
                browser.get(item.get_attribute('href'))
                break
        
        # Creating an array with all the columns names
        stats_table = browser.find_element(By.TAG_NAME, "table")
        columns = stats_table.find_element(By.TAG_NAME, "thead") \
                             .find_elements(By.TAG_NAME, "th")
        columns = [column.text for column in columns]

        # Creating a matrix with all the rows of stats
        rows = stats_table.find_element(By.TAG_NAME, "tbody") \
                          .find_elements(By.TAG_NAME, "tr")
        table = []
        for row in rows:
            stats = row.find_elements(By.TAG_NAME, "td")
            stats = [stat.text for stat in stats]
            table.append(stats)

        return table, columns

# %%
def creating_table(param):
    '''
    Given the return of vlr_stealer.stats_table(), it returns a pandas table


    :param param: return of vlr_stealer.stats_table()
    :return table: pd.DataFrame object
    '''
    linhas, colunas = param
    return pd.DataFrame(linhas, columns=colunas)

# %%
def fixing_info(table, id):
    '''
    removing useless info, adding additional info, fixing columns names, fixing value types

    :param table: pd.DataFrame object
    :return table: pd.DataFrame object with reorganized and fixed values
    '''
    # Removing useless info
    useless_info = ["AGENTS", "RND", "KMAX", "K", "D", "A", "FK", "FD", "CL%"]
    table = table.drop(columns=useless_info)

    # Inserting new column
    table.insert(1, "TEAM", "N/A")
    table.insert(2, "CAMP", id)

    # Fixing columns names
    new_columns = {"R2.0": "RATING", "K:D": "KD", "HS%": "HS"}
    table = table.rename(columns=new_columns)

    # Fixing value types
    colunas_numericas = ["RATING", "ACS", "KD", "ADR", "KPR", "APR", "FKPR", "FDPR"]
    colunas_porcentagem = ["KAST", "HS"]
    table[colunas_numericas] = table[colunas_numericas].astype(float)
    for coluna in colunas_porcentagem:
        table[coluna] = table[coluna].str.replace("%", "").astype(float) / 100

    return table

# %%
def sep_team_player(table):
    '''
    separatting the info of "PLAYER" (previusly player+team) into PLAYER and TEAM

    :param table: pd.DataFrame object
    :return table: pd.DataFrame object
    '''
    for linha in table.index:
        player, time = table.loc[linha, "PLAYER"].split("\n")
        table.loc[linha, "PLAYER"] = player
        table.loc[linha, "TEAM"] = time
    
    return table

# %%
class stats_manager():
    def __init__(self):
        self.table = None
        
        self.players = None
        self.teams = None
        self.tournaments = None

    def get_table(self, param, id):
        self.table = self.__pre_processing_table(param, id)

    def display(self):
        print(self.table)

    def __get_info(self, cur):
        cur.execute("SELECT id, nome FROM players")
        self.players = {nome: id for id, nome in cur.fetchall()}

        cur.execute("SELECT id, tag FROM times")
        self.teams = {tag: id for id, tag in cur.fetchall()}

        cur.execute("SELECT id, url from campeonatos WHERE id=1")
        self.tournaments = {id: url for id, url in cur.fetchall()}

        for player in self.table["PLAYER"]:
            if player not in self.players:
                cur.execute("INSERT INTO players (nome) VALUES (%s) RETURNING id", (player,))
                player_id = cur.fetchone()[0]
                
                self.players[player] = player_id
        
        self.table["TEAM"] = self.table["TEAM"].map(self.teams)
        self.table["PLAYER"] = self.table["PLAYER"].map(self.players)
        

    def save(self):
        with psycopg.connect(DB_URL) as conn:
            with conn.cursor() as cur:
                self.__get_info(cur)

                for row in self.table.itertuples():
                    try:
                        cur.execute(""" 
                                INSERT INTO stats_players (
                                id_player, id_time, id_camp, rating, acs, kd, 
                                kast, adr, kpr, apr, fkpr, fdpr, hs, cl
                                ) 
                                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                                ON CONFLICT (id_player, id_time, id_camp)
                                DO UPDATE SET 
                                    rating = EXCLUDED.rating, 
                                    acs = EXCLUDED.acs, 
                                    kd = EXCLUDED.kd, 
                                    kast = EXCLUDED.kast, 
                                    adr = EXCLUDED.adr, 
                                    kpr = EXCLUDED.kpr, 
                                    apr = EXCLUDED.apr, 
                                    fkpr = EXCLUDED.fkpr, 
                                    fdpr = EXCLUDED.fdpr, 
                                    hs = EXCLUDED.hs, 
                                    cl = EXCLUDED.cl
                                """, 
                                (
                                    row.PLAYER, row.TEAM, row.CAMP, row.RATING, 
                                    row.ACS, row.KD, row.KAST, row.ADR, 
                                    row.KPR, row.APR, row.FKPR, row.FDPR, 
                                    row.HS, row.CL  
                                )
                            )
                    except Exception as e:
                        print(f"ID_PLAYER: {row.PLAYER} (Tipo: {type(row.PLAYER)}), ID_TEAM: {row.TEAM} (Tipo: {type(row.TEAM)}), ID_CAMP: {row.CAMP} (Tipo: {type(row.CAMP)})")
                        raise e

                print(f"Stats of tournament {self.id} saved successfully.")

    def __pre_processing_table(self, param, id):
        table = creating_table(param)
        table = fixing_info(table, id)
        return sep_team_player(table)

# %% [markdown]
# #### Rodar
# Testing the logic before adding it to the save method. .save() shouldn't work if this block is runned, but I didn't tested

# %%
with get_conn() as conn:
    with conn.cursor() as cur:
        cur.execute("SELECT id, nome FROM players")
        players = {nome: id for id, nome in cur.fetchall()}

        cur.execute("SELECT id, tag FROM times")
        teams = {tag: id for id, tag in cur.fetchall()}

        cur.execute("SELECT id, url from campeonatos WHERE id=1")
        camps = cur.fetchall()

# %%
print(players)
print(teams)
print(camps)
# Out:
# {'johnqt': 1, 'dgzin': 2, 'valyn': 3, 'koalanoob': 4, 'Neon': 5, 'Demon1': 6, 'lukxo': 7, 'BABYBAY': 8, 'Cryocells': 9, 'bang': 10, 'Inspire': 11, 'trent': 12, 'Verno': 13, 'brawk': 14, 'mada': 15, 'v1c': 16, 'keiko': 17, 'skuba': 18, 'artzin': 19, 'OXY': 20, 'eeiu': 21, 'leaf': 22, 'Xeppaa': 23, 'supamen': 24, 'zekken': 25, 'Rossy': 26, 'PxS': 27, 'kiNgg': 28, 'keznit': 29, 'vora': 30, 'aspas': 31, 'Mazino': 32, 'Asuna': 33, 'bao': 34, 'penny': 35, 'NagZ': 36, 'Reduxx': 37, 'mta': 38, 'blowz': 39, 'Timotino': 40, 'alym': 41, 'nerve': 42, 'Darker': 43, 'Sato': 44, 'Kyu': 45, 'C0M': 46, 'Ethan': 47, 'benG': 48, 'Okeanos': 49, 'pANcada': 50, 'infiltrator': 51, 'cortezia': 52, 'Eggsterr': 53, 'jawgemo': 54, 'P0PPIN': 55, 'Zellsis': 56, 'tex': 57, 'spike': 58, 'N4RRATE': 59, 'cauanzin': 60, 'Virtyy': 61, 'Governor': 62, 'happywei': 63, 'Yuicaw': 64, 'AAAAY': 65, 'vo0kashu': 66, 'Shr1mp': 67, 'CHICHOO': 68, 'BerLIN': 69, 'f4ngeer': 70, 'whzy': 71, 'splash': 72, 'Erv': 73, 'deLb': 74, 'K1ra': 75, 'Rarga': 76, 'iamgrq': 77, 'Lysoar': 78, 'rushia': 79, 'Haodong': 80, 'yosemite': 81, 'Scales': 82, 'Smoggy': 83, 'Knight': 84, 'OBONE': 85, 'jkuro': 86, 'Setrod': 87, 'stew': 88, 'Kai': 89, 'Coco': 90, 'Dynamite': 91, 'lucas': 92, 'nephh': 93, 'slowly': 94, 'ZmjjKK': 95, 'Nicc': 96, 'jowa': 97, 'qiutiaN': 98, 'cb': 99, 'sword9': 100, 'Viva': 101, 'LuoK1ng': 102, 'SiuFatBB': 103, 'WsLeo': 104, 'GREEN': 105, 'GuanG': 106, 'FengF': 107, 'SpiritZ1': 108, 'coconut': 109, 'NoMan': 110, 'zhe': 111, 'Abo': 112, 'Au1': 113, 'sScary': 114, 'bud': 115, 'Ezeir': 116, 'nobody': 117, 'Biank': 118, 'Flex1n': 119, 'Spring': 120, 'Akeman': 121, 'heybay': 122, 'Life': 123}
# {'G2': 2, '100T': 3, 'EG': 5, 'KRÜ': 6, 'NRG': 7, 'C9': 8, 'LEV': 10, 'LOUD': 11, 'FNC': 13, 'NAVI': 14, 'KC': 15, 'FUT': 16, 'M8': 17, 'GX': 23, 'MIBR': 1, 'SEN': 4, 'FUR': 12, 'ENVY': 9, 'PCF': 18, 'BBL': 19, 'ULF': 20, 'VIT': 21, 'TH': 22, 'TL': 24, 'TE': 25, 'WOL': 26, 'FPX': 27, 'TYL': 28, 'AG': 29, 'NOVA': 30, 'JDG': 31, 'TEC': 32, 'XLG': 33, 'EDG': 34, 'BLG': 35, 'DRG': 36, 'NS': 37, 'TS': 38, 'ZETA': 39, 'FS': 40, 'GE': 41, 'DFM': 42, 'GEN': 43, 'T1': 44, 'PRX': 46, 'RRQ': 47, 'VL': 48, 'FA': 0, 'DRX': 45, 'EF': 49}
# [(1, 'https://www.vlr.gg/event/2685/vct-2026-china-kickoff/main-event')]

# %%
sts_mng = stats_manager()
for id, url in camps:
    param = stats_table(url)
    sts_mng.get_table(param, id)

# %%
sts_mng.display()
# Out:
#       PLAYER  TEAM  CAMP  RATING    ACS    KD  KAST    ADR   KPR   APR  FKPR  \
# 0   happywei   XLG     1    1.33  239.0  1.49  0.77  156.1  0.86  0.37  0.08
# 1     Yuicaw   JDG     1    1.21  210.0  1.05  0.73  146.2  0.71  0.29  0.11
# 2      AAAAY   FPX     1    1.20  200.4  1.07  0.62  147.3  0.76  0.06  0.06
# 3   vo0kashu   DRG     1    1.19  219.9  1.25  0.71  143.9  0.78  0.18  0.05
# 4     Shr1mp    AG     1    1.15  203.9  1.14  0.72  130.9  0.72  0.25  0.08
# ..       ...   ...   ...     ...    ...   ...   ...    ...   ...   ...   ...
# 56    Flex1n   DRG     1    0.85  173.1  0.80  0.70  112.7  0.59  0.38  0.08
# 57    Spring   WOL     1    0.83  182.9  0.84  0.66  111.3  0.63  0.27  0.09
# 58    Akeman   DRG     1    0.82  185.7  0.82  0.66  123.7  0.64  0.21  0.17
# 59    heybay  NOVA     1    0.74  157.7  0.69  0.65   99.2  0.50  0.28  0.02
# 60      Life   FPX     1    0.65  162.9  0.63  0.64  118.9  0.55  0.20  0.13
#
#     FDPR    HS CL
# 0   0.05  0.34
# 1   0.07  0.29
# 2   0.05  0.35
# 3   0.03  0.27
# 4   0.03  0.30
# ..   ...   ... ..
# 56  0.07  0.28
# 57  0.13  0.24
# 58  0.18  0.29
# 59  0.14  0.25
# 60  0.23  0.34
#
# [61 rows x 14 columns]

# %%
sts_mng.table.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PLAYER  61 non-null     str
#  1   TEAM    61 non-null     str
#  2   CAMP    61 non-null     int64
#  3   RATING  61 non-null     float64
#  4   ACS     61 non-null     float64
#  5   KD      61 non-null     float64
#  6   KAST    61 non-null     float64
#  7   ADR     61 non-null     float64
#  8   KPR     61 non-null     float64
#  9   APR     61 non-null     float64
#  10  FKPR    61 non-null     float64
#  11  FDPR    61 non-null     float64
#  12  HS      61 non-null     float64
#  13  CL      61 non-null     str
# dtypes: float64(10), int64(1), str(3)
# memory usage: 6.8 KB

# %%
with get_conn() as conn:
    with conn.cursor() as cur:
        for player in sts_mng.table["PLAYER"]:
            if player not in players:
                cur.execute("INSERT INTO players (nome) VALUES (%s) RETURNING id", (player,))
                player_id = cur.fetchone()[0]
                
                players[player] = player_id

# %%
sts_mng.table["TEAM"] = sts_mng.table["TEAM"].map(teams)
print(sts_mng.table["TEAM"])
# Out:
# 0     33
# 1     31
# 2     27
# 3     36
# 4     29
#       ..
# 56    36
# 57    26
# 58    36
# 59    30
# 60    27
# Name: TEAM, Length: 61, dtype: int64

# %%
sts_mng.table["PLAYER"] = sts_mng.table["PLAYER"].map(players)
print(sts_mng.table["PLAYER"])
# Out:
# 0      63
# 1      64
# 2      65
# 3      66
# 4      67
#      ...
# 56    119
# 57    120
# 58    121
# 59    122
# 60    123
# Name: PLAYER, Length: 61, dtype: int64

# %%
with get_conn() as conn:
    with conn.cursor() as cur:
        sts_mng.get_info(cur)

# %%
sts_mng.display()
# Out:
#     PLAYER  TEAM  CAMP  RATING    ACS    KD  KAST    ADR   KPR   APR  FKPR  \
# 0       63    33     1    1.33  239.0  1.49  0.77  156.1  0.86  0.37  0.08
# 1       64    31     1    1.21  210.0  1.05  0.73  146.2  0.71  0.29  0.11
# 2       65    27     1    1.20  200.4  1.07  0.62  147.3  0.76  0.06  0.06
# 3       66    36     1    1.19  219.9  1.25  0.71  143.9  0.78  0.18  0.05
# 4       67    29     1    1.15  203.9  1.14  0.72  130.9  0.72  0.25  0.08
# ..     ...   ...   ...     ...    ...   ...   ...    ...   ...   ...   ...
# 56     119    36     1    0.85  173.1  0.80  0.70  112.7  0.59  0.38  0.08
# 57     120    26     1    0.83  182.9  0.84  0.66  111.3  0.63  0.27  0.09
# 58     121    36     1    0.82  185.7  0.82  0.66  123.7  0.64  0.21  0.17
# 59     122    30     1    0.74  157.7  0.69  0.65   99.2  0.50  0.28  0.02
# 60     123    27     1    0.65  162.9  0.63  0.64  118.9  0.55  0.20  0.13
#
#     FDPR    HS CL
# 0   0.05  0.34
# 1   0.07  0.29
# 2   0.05  0.35
# 3   0.03  0.27
# 4   0.03  0.30
# ..   ...   ... ..
# 56  0.07  0.28
# 57  0.13  0.24
# 58  0.18  0.29
# 59  0.14  0.25
# 60  0.23  0.34
#
# [61 rows x 14 columns]

# %%
sts_mng.table.info()
players = sts_mng.table["PLAYER"]
times = sts_mng.table["TEAM"]
for player, time in zip(players, times):
    print(f"Player: {player} (Tipo: {type(player)}) - Time: {time} (Tipo: {type(time)})")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   
(Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 74 (Tipo: <class 'int'>)
# ID_TEAM: 25 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 75 (Tipo: <class 'int'>)
# ID_TEAM: 29 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 76 (Tipo: <class 'int'>)
# ID_TEAM: 33 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 77 (Tipo: <class 'int'>)
# ID_TEAM: 29 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 78 (Tipo: <class 'int'>)
# ID_TEAM: 33 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 79 (Tipo: <class 'int'>)
# ID_TEAM: 35 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 80 (Tipo: <class 'int'>)
# ID_TEAM: 32 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 81 (Tipo: <class 'int'>)
# ID_TEAM: 26 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 82 (Tipo: <class 'int'>)
# ID_TEAM: 28 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 83 (Tipo: <class 'int'>)
# ID_TEAM: 34 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 84 (Tipo: <class 'int'>)
# ID_TEAM: 35 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 85 (Tipo: <class 'int'>)
# ID_TEAM: 30 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 86 (Tipo: <class 'int'>)
# ID_TEAM: 31 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 87 (Tipo: <class 'int'>)
# ID_TEAM: 27 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 88 (Tipo: <class 'int'>)
# ID_TEAM: 31 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 89 (Tipo: <class 'int'>)
# ID_TEAM: 25 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 90 (Tipo: <class 'int'>)
# ID_TEAM: 32 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 91 (Tipo: <class 'int'>)
# ID_TEAM: 32 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 92 (Tipo: <class 'int'>)
# ID_TEAM: 32 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 93 (Tipo: <class 'int'>)
# ID_TEAM: 35 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 94 (Tipo: <class 'int'>)
# ID_TEAM: 28 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 95 (Tipo: <class 'int'>)
# ID_TEAM: 34 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 96 (Tipo: <class 'int'>)
# ID_TEAM: 36 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 97 (Tipo: <class 'int'>)
# ID_TEAM: 26 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 98 (Tipo: <class 'int'>)
# ID_TEAM: 26 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 99 (Tipo: <class 'int'>)
# ID_TEAM: 34 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 100 (Tipo: <class 'int'>)
# ID_TEAM: 28 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 101 (Tipo: <class 'int'>)
# ID_TEAM: 25 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 102 (Tipo: <class 'int'>)
# ID_TEAM: 25 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 103 (Tipo: <class 'int'>)
# ID_TEAM: 26 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 104 (Tipo: <class 'int'>)
# ID_TEAM: 33 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 105 (Tipo: <class 'int'>)
# ID_TEAM: 30 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 106 (Tipo: <class 'int'>)
# ID_TEAM: 30 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 107 (Tipo: <class 'int'>)
# ID_TEAM: 25 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 108 (Tipo: <class 'int'>)
# ID_TEAM: 36 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 109 (Tipo: <class 'int'>)
# ID_TEAM: 31 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 110 (Tipo: <class 'int'>)
# ID_TEAM: 33 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 111 (Tipo: <class 'int'>)
# ID_TEAM: 31 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 112 (Tipo: <class 'int'>)
# ID_TEAM: 32 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 113 (Tipo: <class 'int'>)
# ID_TEAM: 29 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 114 (Tipo: <class 'int'>)
# ID_TEAM: 27 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 115 (Tipo: <class 'int'>)
# ID_TEAM: 35 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 116 (Tipo: <class 'int'>)
# ID_TEAM: 30 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 117 (Tipo: <class 'int'>)
# ID_TEAM: 34 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 118 (Tipo: <class 'int'>)
# ID_TEAM: 35 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 119 (Tipo: <class 'int'>)
# ID_TEAM: 36 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 120 (Tipo: <class 'int'>)
# ID_TEAM: 26 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 121 (Tipo: <class 'int'>)
# ID_TEAM: 36 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 122 (Tipo: <class 'int'>)
# ID_TEAM: 30 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
# ID_PLAYER: 123 (Tipo: <class 'int'>)
# ID_TEAM: 27 (Tipo: <class 'int'>)
# ID_CAMP: 1 (Tipo: <class 'int'>)
